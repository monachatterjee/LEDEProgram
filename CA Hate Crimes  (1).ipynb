# %%
import pandas as pd
# Out:
# /Users/chandrimachatterjee/.pyenv/versions/3.8.10/lib/python3.8/site-packages/pandas/compat/__init__.py:109: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)

# %%
df= pd.read_csv("Hate-2001-2020.csv")

# %%
df.head()
# Out:
#           RecordId  ClosedYear  MonthOccurrence  County NCIC  \
# 0  CA01-0000000001        2001                2       1  100
# 1  CA01-0000000005        2001                2       1  100
# 2  CA01-0000000003        2001                5       1  100
# 3  CA01-0000000002        2001                9       1  100
# 4  CA01-0000000004        2001                9       1  100
#
#    TotalNumberOfVictims  TotalNumberOfIndividualVictims SuspectsRaceAsAGroup  \
# 0                     1                               1                White
# 1                     2                               2                White
# 2                     1                               1                White
# 3                     1                               1                White
# 4                     2                               2                White
#
#    TotalNumberOfSuspects                MostSeriousUcr  ...  \
# 0                      2                Simple Assault  ...
# ...

# %%
df.describe()
# Out:
#          ClosedYear  MonthOccurrence        County  TotalNumberOfVictims  \
# count  24436.000000     24436.000000  24436.000000          24436.000000
# mean    2009.346579         6.427525     27.567401              1.209732
# std        6.049120         3.297776     12.890920              0.775260
# min     2001.000000         1.000000      1.000000              1.000000
# 25%     2004.000000         4.000000     19.000000              1.000000
# 50%     2008.000000         6.000000     25.500000              1.000000
# 75%     2015.000000         9.000000     37.000000              1.000000
# max     2020.000000        12.000000     58.000000             50.000000
#
#        TotalNumberOfIndividualVictims  TotalNumberOfSuspects  \
# count                    24436.000000           24436.000000
# mean                         1.073907               1.057702
# std                          0.878512               1.521642
# min                          0.000000               0.000000
# ...

# %%
df.dtypes
# Out:
# RecordId                                   object
# ClosedYear                                  int64
# MonthOccurrence                             int64
# County                                      int64
# NCIC                                       object
# TotalNumberOfVictims                        int64
# TotalNumberOfIndividualVictims              int64
# SuspectsRaceAsAGroup                       object
# TotalNumberOfSuspects                       int64
# MostSeriousUcr                             object
# MostSeriousUcrType                         object
# MostSeriousLocation                        object
# MostSeriousBias                            object
# MostSeriousBiasType                        object
# MostSeriousVictimType                      object
# WeaponType                                 object
# Offensive_Act                              object
# IsMultipleBias                             object
# TotalNumberOfIndividualVictimsAdult       float64
# ...

# %%
df.MostSeriousBias.describe()
# Out:
# count                              24436
# unique                                35
# top       Anti-Black or African American
# freq                                7508
# Name: MostSeriousBias, dtype: object

# %%
df.MostSeriousBiasType.describe()
# Out:
# count                       24436
# unique                          6
# top       Race/Ethnicity/Ancestry
# freq                        14696
# Name: MostSeriousBiasType, dtype: object

# %%
df.Offensive_Act.describe()
# Out:
# count            24074
# unique              14
# top       Verbal slurs
# freq             11043
# Name: Offensive_Act, dtype: object

# %%
df.TotalNumberOfIndividualVictims.count()
# Out:
# 24436

# %%
df.TotalNumberOfIndividualVictimsJuvenile.count()
# Out:
# 5963

# %%
df.SuspectsEthnicityAsAGroup.describe()
# Out:
# count        4813
# unique          4
# top       Unknown
# freq         2566
# Name: SuspectsEthnicityAsAGroup, dtype: object

# %%
df.SuspectsRaceAsAGroup.hist()
# Out:
# <AxesSubplot:>

# %%
df['County'].value_counts().head(10)
#county19 is Los Angeles
# Out:
# 19    9270
# 37    2331
# 38    1541
# 33    1252
# 30    1224
# 43    1090
# 1     1012
# 34     823
# 36     627
# 7      541
# Name: County, dtype: int64

# %%
df.index
# Out:
# RangeIndex(start=0, stop=24436, step=1)

# %%
df.columns
# Out:
# Index(['RecordId', 'ClosedYear', 'MonthOccurrence', 'County', 'NCIC',
#        'TotalNumberOfVictims', 'TotalNumberOfIndividualVictims',
#        'SuspectsRaceAsAGroup', 'TotalNumberOfSuspects', 'MostSeriousUcr',
#        'MostSeriousUcrType', 'MostSeriousLocation', 'MostSeriousBias',
#        'MostSeriousBiasType', 'MostSeriousVictimType', 'WeaponType',
#        'Offensive_Act', 'IsMultipleBias',
#        'TotalNumberOfIndividualVictimsAdult',
#        'TotalNumberOfIndividualVictimsJuvenile', 'TotalNumberOfSuspectsAdult',
#        'TotalNumberOfSuspectsJuvenile', 'SuspectsEthnicityAsAGroup'],
#       dtype='object')

# %%
df['MostSeriousUcrType'].value_counts().head(10)
# Out:
# Violent Crimes     15775
# Property Crimes     8661
# Name: MostSeriousUcrType, dtype: int64

# %%
df['MostSeriousBiasType'].value_counts().head(10)
# Out:
# Race/Ethnicity/Ancestry    14696
# Sexual Orientation          5164
# Religion                    4037
# Gender Nonconforming         397
# Disability                    84
# Gender                        58
# Name: MostSeriousBiasType, dtype: int64

# %%
df['Offensive_Act'].value_counts().head(10)
# Out:
# Verbal slurs                          11043
# Graffiti                               4968
# Other                                  2889
# Daubing of swastika                    1568
# Damage to vehicle                      1242
# Annoying telephone calls/fax            980
# Threatening letters/flyers/email        978
# Rock throwing                           227
# Unknown                                  63
# Disturbing public assembly/meeting       30
# Name: Offensive_Act, dtype: int64

# %%
df['MostSeriousUcr'].value_counts().head(10)
# Out:
# Destruction/Damage/Vandalism    8039
# Intimidation                    5826
# Simple Assault                  5189
# Aggravated Assault              3903
# Robbery                          807
# Burglary                         357
# Arson                            146
# Larceny-Theft                    104
# Murder                            26
# Rape                              24
# Name: MostSeriousUcr, dtype: int64

# %%
df = pd.read_excel("Hate2010-2020.xlsx")
#Itookoutyearstofocusonlyon10latestyears

# %%
df.head()
# Out:
#           RecordId  ClosedYear  MonthOccurrence  County NCIC  \
# 0  CA00-0000023703        2010                2       1  101
# 1  CA00-0000023704        2010                3       1  101
# 2  CA00-0000023922        2010                1       1  102
# 3  CA00-0000024218        2010                7       1  102
# 4  CA00-0000024544        2010               10       1  102
#
#    TotalNumberOfVictims  TotalNumberOfIndividualVictims SuspectsRaceAsAGroup  \
# 0                     1                               1             Hispanic
# 1                     1                               0              Unknown
# 2                     1                               0             Hispanic
# 3                     1                               0              Unknown
# 4                     1                               1                White
#
#    TotalNumberOfSuspects                MostSeriousUcr  ...  \
# 0                      1                  Intimidation  ...
# ...

# %%
df.describe()
# Out:
#          ClosedYear  MonthOccurrence        County  TotalNumberOfVictims  \
# count  10990.000000     10990.000000  10990.000000          10990.000000
# mean    2015.179800         6.461056     26.924295              1.196724
# std        3.321666         3.305106     13.329446              0.733894
# min     2010.000000         1.000000      1.000000              1.000000
# 25%     2012.000000         4.000000     19.000000              1.000000
# 50%     2015.000000         7.000000     19.000000              1.000000
# 75%     2018.000000         9.000000     37.000000              1.000000
# max     2020.000000        12.000000     58.000000             47.000000
#
#        TotalNumberOfIndividualVictims  TotalNumberOfSuspects  IsMultipleBias  \
# count                    10990.000000           10990.000000            23.0
# mean                         1.046588               0.980619             1.0
# std                          0.849496               1.279022             0.0
# ...

# %%
df.dtypes
# Out:
# RecordId                                   object
# ClosedYear                                  int64
# MonthOccurrence                             int64
# County                                      int64
# NCIC                                       object
# TotalNumberOfVictims                        int64
# TotalNumberOfIndividualVictims              int64
# SuspectsRaceAsAGroup                       object
# TotalNumberOfSuspects                       int64
# MostSeriousUcr                             object
# MostSeriousUcrType                         object
# MostSeriousLocation                        object
# MostSeriousBias                            object
# MostSeriousBiasType                        object
# MostSeriousVictimType                      object
# WeaponType                                 object
# Offensive_Act                              object
# IsMultipleBias                            float64
# TotalNumberOfIndividualVictimsAdult       float64
# ...

# %%
df.columns
# Out:
# Index(['RecordId', 'ClosedYear', 'MonthOccurrence', 'County', 'NCIC',
#        'TotalNumberOfVictims', 'TotalNumberOfIndividualVictims',
#        'SuspectsRaceAsAGroup', 'TotalNumberOfSuspects', 'MostSeriousUcr',
#        'MostSeriousUcrType', 'MostSeriousLocation', 'MostSeriousBias',
#        'MostSeriousBiasType', 'MostSeriousVictimType', 'WeaponType',
#        'Offensive_Act', 'IsMultipleBias',
#        'TotalNumberOfIndividualVictimsAdult',
#        'TotalNumberOfIndividualVictimsJuvenile', 'TotalNumberOfSuspectsAdult',
#        'TotalNumberOfSuspectsJuvenile', 'SuspectsEthnicityAsAGroup'],
#       dtype='object')

# %%
df['County'].value_counts().head(10)
#ThisshowsLAisstilltopcounty
# Out:
# 19    4106
# 37    1054
# 1      608
# 30     581
# 43     531
# 38     517
# 33     449
# 36     331
# 34     297
# 7      296
# Name: County, dtype: int64

# %%
df['MostSeriousUcrType'].value_counts().head(10)
# Out:
# Violent Crimes     7026
# Property Crimes    3964
# Name: MostSeriousUcrType, dtype: int64

# %%
df['MostSeriousBiasType'].value_counts().head(10)
# Out:
# Race/Ethnicity/Ancestry    6180
# Sexual Orientation         2486
# Religion                   1960
# Gender Nonconforming        277
# Disability                   51
# Gender                       36
# Name: MostSeriousBiasType, dtype: int64

# %%
df['MostSeriousBiasType'].value_counts().plot(kind='barh')
# Out:
# <AxesSubplot:>

# %%
df['MostSeriousUcr'].value_counts().plot(kind='barh')
# Out:
# <AxesSubplot:>

# %%
import matplotlib.pyplot as plt

# %%
plt.style.use('fivethirtyeight')

# %%
df['MostSeriousUcr'].value_counts().plot(kind='barh')
# Out:
# <AxesSubplot:>

# %%
df['MostSeriousBiasType'].value_counts().plot(kind='barh')
# Out:
# <AxesSubplot:>

# %%
df.groupby('MostSeriousBiasType')['MostSeriousUcr'].value_counts()
# Out:
# MostSeriousBiasType      MostSeriousUcr
# Disability               Simple Assault                    16
#                          Aggravated Assault                11
#                          Destruction/Damage/Vandalism      10
#                          Intimidation                      10
#                          Larceny-Theft                      2
#                          Robbery                            2
# Gender                   Intimidation                      15
#                          Destruction/Damage/Vandalism      11
#                          Aggravated Assault                 5
#                          Simple Assault                     4
#                          Arson                              1
# Gender Nonconforming     Aggravated Assault                94
#                          Simple Assault                    92
#                          Intimidation                      53
# ...

# %%
df.groupby('MostSeriousBiasType')['MostSeriousUcr'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='MostSeriousBiasType,MostSeriousUcr'>

# %%
df[df['MostSeriousBiasType'] == 'Race/Ethnicity/Ancestry']['MostSeriousUcr'].value_counts().plot(kind='barh')
#this is saying that the main hate crime within the anti-race/ethnic/ancestry motivation, is property destruction/damage
# Out:
# <AxesSubplot:>

# %%
df[df['MostSeriousBiasType'] == 'Race/Ethnicity/Ancestry']['Offensive_Act'].value_counts()
#The most serious offensive act (different than above) is verbal slurs
# Out:
# Verbal slurs                          2877
# Graffiti                              1229
# Other                                  919
# Damage to vehicle                      421
# Threatening letters/flyers/email       211
# Daubing of swastika                    182
# Annoying telephone calls/fax            96
# Rock throwing                           72
# Unknown                                 23
# Hanging in Effigy                       16
# Disturbing public assembly/meeting       7
# Explosion                                5
# Cross burning                            4
# Bombing                                  3
# Name: Offensive_Act, dtype: int64

# %%
df[df['ClosedYear'] == 2010]['Offensive_Act'].value_counts()
# Out:
# Verbal slurs                          447
# Graffiti                              261
# Other                                 142
# Damage to vehicle                      75
# Daubing of swastika                    68
# Annoying telephone calls/fax           45
# Threatening letters/flyers/email       42
# Rock throwing                          13
# Hanging in Effigy                       6
# Disturbing public assembly/meeting      1
# Explosion                               1
# Unknown                                 1
# Cross burning                           1
# Name: Offensive_Act, dtype: int64

# %%
df[df['ClosedYear'] == 2011]['Offensive_Act'].value_counts()
# Out:
# Verbal slurs                        436
# Graffiti                            244
# Other                               146
# Daubing of swastika                  75
# Damage to vehicle                    71
# Threatening letters/flyers/email     35
# Annoying telephone calls/fax         29
# Rock throwing                        13
# Bombing                               2
# Unknown                               1
# Cross burning                         1
# Name: Offensive_Act, dtype: int64

# %%
df[df['ClosedYear'] == 2012]['Offensive_Act'].value_counts()
# Out:
# Verbal slurs                          396
# Graffiti                              208
# Other                                 135
# Damage to vehicle                      59
# Daubing of swastika                    47
# Threatening letters/flyers/email       33
# Annoying telephone calls/fax           20
# Rock throwing                           7
# Disturbing public assembly/meeting      3
# Unknown                                 3
# Explosion                               2
# Hanging in Effigy                       2
# Bombing                                 1
# Name: Offensive_Act, dtype: int64

# %%
df[df['ClosedYear'] == 2013]['Offensive_Act'].value_counts()
# Out:
# Verbal slurs                        346
# Graffiti                            206
# Other                               116
# Damage to vehicle                    55
# Daubing of swastika                  38
# Threatening letters/flyers/email     35
# Annoying telephone calls/fax         17
# Rock throwing                        11
# Unknown                               2
# Cross burning                         2
# Bombing                               1
# Explosion                             1
# Hanging in Effigy                     1
# Name: Offensive_Act, dtype: int64

# %%
df[df['ClosedYear'] == 2014]['Offensive_Act'].value_counts()
# Out:
# Verbal slurs                          282
# Other                                 168
# Graffiti                              150
# Damage to vehicle                      64
# Threatening letters/flyers/email       28
# Daubing of swastika                    28
# Annoying telephone calls/fax           16
# Rock throwing                           6
# Disturbing public assembly/meeting      2
# Unknown                                 2
# Cross burning                           2
# Hanging in Effigy                       1
# Name: Offensive_Act, dtype: int64

# %%
df[df['ClosedYear'] == 2015]['Offensive_Act'].value_counts()
# Out:
# Verbal slurs                        335
# Other                               190
# Graffiti                            142
# Damage to vehicle                    55
# Daubing of swastika                  38
# Threatening letters/flyers/email     26
# Annoying telephone calls/fax         18
# Rock throwing                         7
# Unknown                               3
# Explosion                             2
# Cross burning                         2
# Name: Offensive_Act, dtype: int64

# %%
df[df['ClosedYear'] == 2016]['Offensive_Act'].value_counts()
# Out:
# Verbal slurs                          351
# Graffiti                              217
# Other                                 180
# Damage to vehicle                      52
# Threatening letters/flyers/email       48
# Daubing of swastika                    36
# Annoying telephone calls/fax           22
# Rock throwing                           9
# Unknown                                 5
# Disturbing public assembly/meeting      3
# Explosion                               1
# Cross burning                           1
# Hanging in Effigy                       1
# Name: Offensive_Act, dtype: int64

# %%
df[df['ClosedYear'] == 2017]['Offensive_Act'].value_counts()
# Out:
# Verbal slurs                          428
# Graffiti                              237
# Other                                 200
# Damage to vehicle                      58
# Threatening letters/flyers/email       45
# Daubing of swastika                    45
# Annoying telephone calls/fax           28
# Rock throwing                          13
# Unknown                                 6
# Disturbing public assembly/meeting      3
# Explosion                               2
# Bombing                                 1
# Cross burning                           1
# Name: Offensive_Act, dtype: int64

# %%
df[df['ClosedYear'] == 2018]['Offensive_Act'].value_counts()
# Out:
# Verbal slurs                        506
# Other                               181
# Graffiti                            177
# Damage to vehicle                    63
# Daubing of swastika                  54
# Threatening letters/flyers/email     30
# Annoying telephone calls/fax         19
# Rock throwing                        16
# Unknown                               4
# Hanging in Effigy                     3
# Explosion                             1
# Cross burning                         1
# Name: Offensive_Act, dtype: int64

# %%
df[df['ClosedYear'] == 2019]['Offensive_Act'].value_counts()
# Out:
# Verbal slurs                          454
# Graffiti                              201
# Other                                 181
# Damage to vehicle                      44
# Daubing of swastika                    40
# Threatening letters/flyers/email       39
# Annoying telephone calls/fax           21
# Rock throwing                          10
# Unknown                                10
# Disturbing public assembly/meeting      1
# Bombing                                 1
# Name: Offensive_Act, dtype: int64

# %%
df[df['ClosedYear'] == 2020]['Offensive_Act'].value_counts()
# Out:
# Verbal slurs                          644
# Graffiti                              229
# Other                                 212
# Damage to vehicle                      65
# Threatening letters/flyers/email       43
# Daubing of swastika                    41
# Rock throwing                          20
# Annoying telephone calls/fax           16
# Unknown                                 7
# Disturbing public assembly/meeting      4
# Hanging in Effigy                       4
# Name: Offensive_Act, dtype: int64

# %%
df.groupby("ClosedYear")['Offensive_Act'].value_counts().head(60)
# Out:
# ClosedYear  Offensive_Act
# 2010        Verbal slurs                          447
#             Graffiti                              261
#             Other                                 142
#             Damage to vehicle                      75
#             Daubing of swastika                    68
#             Annoying telephone calls/fax           45
#             Threatening letters/flyers/email       42
#             Rock throwing                          13
#             Hanging in Effigy                       6
#             Cross burning                           1
#             Disturbing public assembly/meeting      1
#             Explosion                               1
#             Unknown                                 1
# 2011        Verbal slurs                          436
#             Graffiti                              244
#             Other                                 146
#             Daubing of swastika                    75
# ...

# %%
df.groupby("ClosedYear")['Offensive_Act'].value_counts().tail(60)
# Out:
# ClosedYear  Offensive_Act
# 2016        Verbal slurs                          351
#             Graffiti                              217
#             Other                                 180
#             Damage to vehicle                      52
#             Threatening letters/flyers/email       48
#             Daubing of swastika                    36
#             Annoying telephone calls/fax           22
#             Rock throwing                           9
#             Unknown                                 5
#             Disturbing public assembly/meeting      3
#             Cross burning                           1
#             Explosion                               1
#             Hanging in Effigy                       1
# 2017        Verbal slurs                          428
#             Graffiti                              237
#             Other                                 200
#             Damage to vehicle                      58
# ...

# %%
df.groupby("ClosedYear")['Offensive_Act'].value_counts().plot(kind='barh')
# Out:
# <AxesSubplot:ylabel='ClosedYear,Offensive_Act'>

# %%
df.groupby("ClosedYear")['MostSeriousBiasType'].value_counts().head(60)
# Out:
# ClosedYear  MostSeriousBiasType
# 2010        Race/Ethnicity/Ancestry    613
#             Sexual Orientation         279
#             Religion                   198
#             Gender Nonconforming        11
#             Disability                   5
#             Gender                       1
# 2011        Race/Ethnicity/Ancestry    587
#             Sexual Orientation         246
#             Religion                   202
#             Gender Nonconforming        11
#             Disability                   7
#             Gender                       7
# 2012        Race/Ethnicity/Ancestry    529
#             Sexual Orientation         235
#             Religion                   146
#             Gender Nonconforming        14
#             Gender                       4
#             Disability                   2
# 2013        Race/Ethnicity/Ancestry    490
#             Sexual Orientation         218
#             Religion                   129
# ...

# %%
df.groupby("ClosedYear")['MostSeriousBiasType'].value_counts().tail(60)
# Out:
# ClosedYear  MostSeriousBiasType
# 2010        Gender                       1
# 2011        Race/Ethnicity/Ancestry    587
#             Sexual Orientation         246
#             Religion                   202
#             Gender Nonconforming        11
#             Disability                   7
#             Gender                       7
# 2012        Race/Ethnicity/Ancestry    529
#             Sexual Orientation         235
#             Religion                   146
#             Gender Nonconforming        14
#             Gender                       4
#             Disability                   2
# 2013        Race/Ethnicity/Ancestry    490
#             Sexual Orientation         218
#             Religion                   129
#             Gender Nonconforming        25
#             Disability                   1
# 2014        Race/Ethnicity/Ancestry    415
#             Sexual Orientation         187
#             Religion                   128
# ...
